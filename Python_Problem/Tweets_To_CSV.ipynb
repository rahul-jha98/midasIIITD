# %%
# You need to fill this with your own api key to enable the below codes to make api call
my_key = {
    'app_key':'',
    'app_secret':'',
    'oauth_token':'',
    'oauth_token_secret':''
}

# %%
# Run this to make sure you have tweepy installed in your environment
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/d5/5f/daac4b4e9b30d7d2a6fdd16a880ff79f27918fe388e4dfc1983dec3a9876/tweepy-3.7.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /home/rahul/anaconda3/lib/python3.7/site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in /home/rahul/anaconda3/lib/python3.7/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in /home/rahul/anaconda3/lib/python3.7/site-packages (from tweepy) (2.21.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
#     100% |████████████████████████████████| 143kB 498kB/s ta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /home/rahul/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/rahul/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/rahul/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/rahul/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.0.1 requests-oauthlib-1.2.0 tweepy-3.7.0

# %% [markdown]
# # Main Code

# %% [markdown]
# ### Importing the libraries
#
# All the libraries needed are imported here
#
# **tweepy** => the library used for accessing the twitter API
#
# **numpy and pandas** => making the data in a presentable format and exporting to csv

# %%
import tweepy
from tweepy import OAuthHandler

import numpy as np
import pandas as pd

# %% [markdown]
# Now we need to attach our api key with each request we make with tweepy. For this we make a auth object which help the api for the authorization and then set up tweepy to use the auth object for every request.
#
# The final object twitterAPI is our entry point to the twitter API using tweepy

# %%
# Here I am creating the auth object
auth = OAuthHandler(my_key['app_key'], my_key['app_secret'])
auth.set_access_token(my_key['oauth_token'], my_key['oauth_token_secret'])

# Linking the auth object with tweepy
twitterAPI = tweepy.API(auth)

# %% [markdown]
# ##### getAllTweets Function
# The Function **getAllTweets** take in the screen name(Default = 'midasIIITD').
#
# Then it gets one tweet to intiate the loop. It then keeps querying for older tweets until the tweets are exhausted. This way we finally get all the tweets in a list called alltweets which we finally return

# %%
def getAllTweets(screenName = 'midasIIITD'):
    alltweets = []
    
    # Getting only 1 tweet to initiate the connection and to have atleast one element in alltweets
    tweets = twitterAPI.user_timeline(screen_name = screenName, exclude_replies = True, count = 1)
    # Adding it to alltweets
    alltweets.extend(tweets)
        
    #save the id of the oldest tweet(currently the only tweet if any)
    oldest = alltweets[-1].id - 1
    
    # While we are able to find any older tweet
    while len(tweets) > 0:
        # Getting next 200 tweets as max tweet that can be queried is 200, 
        # also we need older than the id stored in oldest
        tweets = twitterAPI.user_timeline(screen_name = screenName,count=200,max_id=oldest)
        
        # add them to alltweets
        alltweets.extend(tweets)
        # updating oldtweets to prepare for next iteration
        oldest = alltweets[-1].id - 1
    
    return alltweets

# %% [markdown]
# ##### extractAllDataFromTweetList Function
# The Function **extractAllDataFromTweetList** take in the tweet list as input parameter
#
# Then it gets one by one through all the tweets and removes all retweeted tweets and replies. Then it counts if any media file is present. Finally it adds all the desired data from current tweet into **data** object and adds it to tweet_data
#
# It returns tweet_data a list of desrired data from all the fields

# %%
def extractAllDataFromTweetList(tweet_list):
    # Beginning with a empty list
    tweet_data = []
    
    #Going through each tweet
    for tweet in tweet_list:
        # Removing any retweets
        if (not tweet.retweeted) and ('RT @' not in tweet.text):
            # Removing any replies in the list
            if tweet.in_reply_to_status_id is None:
                
                # In the try block we are accessing the entities with tag media. 
                try:
                    count = 0
                    for medium in tweet.entities['media']:
                        # If it is an photo type then increment count
                        if medium['type'] == 'photo':
                            count += 1
                
                    # If count is 0 update to None as given in question
                    if(count == 0):
                          count = None
                except:
                    # If there was an exception accessing entities or media 
                    # we land here and set count to be None
                    count = None
                
                finally:
                    # Finally we append all the data in a list object called data
                    data = [tweet.text, 
                            tweet.created_at.date(), 
                            tweet.created_at.time(), 
                            tweet.favorite_count, 
                            tweet.retweet_count, 
                            count]
                    # Append it to tweet_data which is used to store all the tweets data in a list
                    tweet_data.append(data)
    
    
    return tweet_data

# %%
# call getAllTweets using default value midasIIITD for screenName in getAllTweets
all_tweets = getAllTweets()

# %%
# call extractAllDataFromTweetList to get the list of infromation extracted from the tweets list
tweets_data = extractAllDataFromTweetList(all_tweets)

# %%
# Converting the list to a dataframe
tweets_data_frame = pd.DataFrame(np.array(tweets_data), columns=['Text', 'Date', 'Time', 'Favorite Count', 'Retweets Count', 'No of Images'])

# %%
# Visualising the result
tweets_data_frame
# Out:
#                                                   Text        Date      Time  \
# 0    Many Congratulations to @midasIIITD student, S...  2019-04-08  07:08:12
# 1    @midasIIITD thanks all students who have appea...  2019-04-08  03:27:42
# 2    We request all students whose interview are sc...  2019-04-07  11:43:24
# 3    Other queries: "none of the Tweeter Apis give ...  2019-04-07  06:55:19
# 4    Other queries: "do we have to make two differe...  2019-04-07  06:53:38
# 5    Other queries: "If using Twitter api, it does ...  2019-04-07  05:32:27
# 6    Response to some queries asked by students on ...  2019-04-07  05:29:40
# 7    We have emailed the task details to all candid...  2019-04-05  16:08:37
# 8    Dear @midasIIITD internship candidates who hav...  2019-04-02  04:20:13
# 9    Looking forward to your paper submission to @I...  2019-04-02  02:44:54
# 10   Online application for https://t.co/DJFDrQsHZP...  2019-04-01  06:53:08
# 11   Congratulations! @midasIIITD team, @isarth23 @...  2019-03-29  17:02:24
# 12   Dr. Vineeth N Balasubramanian will present a T...  2019-03-27  16:09:09
# 13   Thanks to all shortlisted candidates for submi...  2019-03-26  18:12:27
# 14   Congratulations @midasIIITD students Simra Sha...  2019-03-25  13:01:57
# 15   The last date for submitting a solution for th...  2019-03-24  18:44:01
# 16   @IEEEBigMM19 is also available on Facebook now...  2019-03-20  08:19:24
# 115  We are on Facebook too. Like our page to get o...  2018-07-23  16:25:05
# 116  MIDAS is a group of researchers at IIIT-Delhi ...  2018-07-23  12:53:15
#
#     Favorite Count Retweets Count No of Images
# 0               13              2         None
# 1                5              0         None
# 2                1              1         None
# 3                5              2         None
# 4                4              1         None
# 5                6              1         None
# 6                7              1         None
# 7               11              1         None
# 8                8              1         None
# 9                5              1         None
# 10               7              2         None
# 11               9              1         None
# 12               4              1         None
# 13               5              1         None
# 14              18              1         None
# 15               8              3         None
# 16               1              1         None
# 17               6              3         None
# 18              15              4         None
# 19               7              0         None
# 20               2              1         None
# 21               7              2         None
# 22               7              2         None
# 23              16              4         None
# 24               4              0         None
# 25               8              4         None
# 26               9              1         None
# 27               6              2         None
# 28               7              1         None
# 29               2              1         None
# ..             ...            ...          ...
# 87               5              1         None
# 88               3              1         None
# 89               3              3         None
# 90               0              0         None
# 91               7              0         None
# 92               6              1         None
# 93               7              2         None
# 94               8              1            1
# 95               8              3         None
# 96               4              2         None
# 97               4              1         None
# 98               3              1         None
# 99               9              0         None
# 100              7              3         None
# 101              3              1         None
# 102              2              0         None
# 103              2              1         None
# 104              1              1         None
# 105              1              1         None
# 106              1              1         None
# 107              6              1         None
# 108              1              0         None
# 109              3              2         None
# 110              8              2         None
# 111              5              1         None
# 112              2              1         None
# 113              2              1         None
# 114              4              1            1
# 115              3              1         None
# 116              7              4         None
#
# [117 rows x 6 columns]

# %%
# Write the data frame to a csv file
tweets_data_frame.to_csv('midasIIITD_Tweets.csv', index = False)

# %%
# Check if reading the csv gives same output
pd.read_csv('midasIIITD_Tweets')
# Out:
#                                                   Text        Date      Time  \
# 0    Many Congratulations to @midasIIITD student, S...  2019-04-08  07:08:12
# 1    @midasIIITD thanks all students who have appea...  2019-04-08  03:27:42
# 2    We request all students whose interview are sc...  2019-04-07  11:43:24
# 3    Other queries: "none of the Tweeter Apis give ...  2019-04-07  06:55:19
# 4    Other queries: "do we have to make two differe...  2019-04-07  06:53:38
# 5    Other queries: "If using Twitter api, it does ...  2019-04-07  05:32:27
# 6    Response to some queries asked by students on ...  2019-04-07  05:29:40
# 7    We have emailed the task details to all candid...  2019-04-05  16:08:37
# 8    Dear @midasIIITD internship candidates who hav...  2019-04-02  04:20:13
# 9    Looking forward to your paper submission to @I...  2019-04-02  02:44:54
# 10   Online application for https://t.co/DJFDrQsHZP...  2019-04-01  06:53:08
# 11   Congratulations! @midasIIITD team, @isarth23 @...  2019-03-29  17:02:24
# 12   Dr. Vineeth N Balasubramanian will present a T...  2019-03-27  16:09:09
# 13   Thanks to all shortlisted candidates for submi...  2019-03-26  18:12:27
# 14   Congratulations @midasIIITD students Simra Sha...  2019-03-25  13:01:57
# 15   The last date for submitting a solution for th...  2019-03-24  18:44:01
# 16   @IEEEBigMM19 is also available on Facebook now...  2019-03-20  08:19:24
# 17   BigMM 2019 : IEEE BigMM 2019 – Call for Worksh...  2019-03-18  02:27:47
# 18   Congratulations @midasIIITD team, Rohan, Prady...  2019-03-17  14:22:04
#
#      Favorite Count  Retweets Count  No of Images
# 0                13               2           NaN
# 1                 5               0           NaN
# 2                 1               1           NaN
# 3                 5               2           NaN
# 4                 4               1           NaN
# 5                 6               1           NaN
# 6                 7               1           NaN
# 7                11               1           NaN
# 8                 8               1           NaN
# 9                 5               1           NaN
# 10                7               2           NaN
# 11                9               1           NaN
# 12                4               1           NaN
# 13                5               1           NaN
# 14               18               1           NaN
# 15                8               3           NaN
# 16                1               1           NaN
# 17                6               3           NaN
# 18               15               4           NaN
# 19                7               0           NaN
# 20                2               1           NaN
# 21                7               2           NaN
# 22                7               2           NaN
# 23               16               4           NaN
# 24                4               0           NaN
# 25                8               4           NaN
# 26                9               1           NaN
# 27                6               2           NaN
# 28                7               1           NaN
# 29                2               1           NaN
# ..              ...             ...           ...
# 87                5               1           NaN
# 88                3               1           NaN
# 89                3               3           NaN
# 90                0               0           NaN
# 91                7               0           NaN
# 92                6               1           NaN
# 93                7               2           NaN
# 94                8               1           1.0
# 95                8               3           NaN
# 96                4               2           NaN
# 97                4               1           NaN
# 98                3               1           NaN
# 99                9               0           NaN
# 100               7               3           NaN
# 101               3               1           NaN
# 102               2               0           NaN
# 103               2               1           NaN
# 104               1               1           NaN
# 105               1               1           NaN
# 106               1               1           NaN
# 107               6               1           NaN
# 108               1               0           NaN
# 109               3               2           NaN
# 110               8               2           NaN
# 111               5               1           NaN
# 112               2               1           NaN
# 113               2               1           NaN
# 114               4               1           1.0
# 115               3               1           NaN
# 116               7               4           NaN
#
# [117 rows x 6 columns]

# %% [markdown]
# ## The scripts below are commented out version of the trail code

# %% [markdown]
# ## The working behind the code
#
# The code below is the one that I executed to make the runnig model of the script. This is the rough version of the code and should not be executed

# %%
# import tweepy #https://github.com/tweepy/tweepy
# import csv
# from tweepy import OAuthHandler

# %%
# auth = OAuthHandler(auth_params['app_key'], auth_params['app_secret'])
# auth.set_access_token(auth_params['oauth_token'], auth_params['oauth_token_secret'])

# %%
# api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
# alltweets = []

# %%
# tweets = api.user_timeline(screen_name = 'midasIIITD', exclude_replies = True, count = 1)

# %%
# alltweets.extend(tweets)

# %%
# #save the id of the oldest tweet less one
# oldest = alltweets[-1].id - 1

# %%
#  while len(tweets) > 0:
#     tweets = api.user_timeline(screen_name = 'midasIIITD',count=200,max_id=oldest)
#     alltweets.extend(tweets)
#     oldest = alltweets[-1].id - 1

# %%
# tweet_data = []

# %%
# for tweet in alltweets:
#     if (not tweet.retweeted) and ('RT @' not in tweet.text):
#         if tweet.in_reply_to_status_id is None:
#             try:
#                 count = 0
#                 for medium in tweet.entities['media']:
#                       if medium['type'] == 'photo':
#                           count += 1
                
#                 if(count == 0):
#                       count = None
#             except:
#                 count = None
#             finally:
#                 data = [tweet.text, tweet.created_at.date(), tweet.created_at.time(), tweet.favorite_count, tweet.retweet_count, count]
#                 tweet_data.append(data)

# %%
# import numpy as np
# import pandas as pd
# tweet_data = np.array(tweet_data)

# %%
# pd.DataFrame(tweet_data, columns=['Text', 'Date', 'Time', 'Favorite Count', 'Retweets Count', 'No of Images'])
# 266  Check more details of the 20th IEEE Internatio...  2018-08-07  02:05:12
# 267  MR2AMC@ISM 2018 will be organized by @RatnRaji...  2018-08-07  01:58:49
# 268  Our workshop proposal named, "MR2AMC: Multimod...  2018-08-07  01:50:33
# 269  RT @goodfellow_ian: One of the most anticipate...  2018-08-06  17:46:59
# 270  Congratulation @soujanyaporia for being appoin...  2018-08-03  05:56:33
# 271  RT @IIITDelhi: Congratulations @midasIIITD int...  2018-08-01  11:20:07
# 272  RT @learning_pt: Profile of the 5 Indian under...  2018-08-01  05:06:47
# 273  Have a look at the list of accepted papers in ...  2018-07-31  12:11:52
# 274  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...  2018-07-31  02:06:26
# 275  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...  2018-07-30  07:30:51
# 276  RT @ylecun: Jitendra Malik, who directs FAIR-M...  2018-07-28  11:07:11
# 277  RT @kdnuggets: .@Bloomberg launches free cours...  2018-07-28  06:14:09
# 278  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...  2018-07-28  06:13:48
# 279  RT @IIITDelhi: We are delighted to announce th...  2018-07-28  04:08:21
# 280  Get ready for the annual technical fest of @II...  2018-07-27  06:46:44
# 281  Congratulations Dr. @RatnRajiv and team @midas...  2018-07-27  04:07:31
# 282  Congratulations MIDAS @midasIIITD intern Prakh...  2018-07-25  05:14:35
# 283    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm  2018-07-24  10:33:23
# 284  It feels great to be the part of @IIITDelhi. h...  2018-07-24  10:12:34
# 285  Thank you, @toonzratn for designing the logo o...  2018-07-24  09:46:26
# 286  We are on Facebook too. Like our page to get o...  2018-07-23  16:25:05
# 287  MIDAS is a group of researchers at IIIT-Delhi ...  2018-07-23  12:53:15
#
#     Favorite Count Retweets Count No of Images
# 0                0             33         None
# 1                0             12         None
# 2                0             15         None
# 3               13              2         None
# 4                5              0         None
# 5                1              1         None
# 6                5              2         None
# 7                4              1         None
# 8                6              1         None
# 9                7              1         None
# 10               0              2         None
# 11              11              1         None
# 12               0             16         None
# 13               0             11            1
# 14               0             59         None
# 15               0            870         None
# 16               0             16         None
# 17               0              4         None
# 18               8              1         None
# 19               5              1         None
# 20               0              7         None
# 21               7              2         None
# 22               0             10         None
# 23               0              2         None
# 24               0              1         None
# 25               9              1         None
# 26               0            718         None
# 27               0            156         None
# 28               4              1         None
# 29               0           1545         None
# ..             ...            ...          ...
# 258              0              2         None
# 259              0              2         None
# 260              2              0         None
# 261              0            111            1
# 262              0            265         None
# 263              2              1         None
# 264              0              1         None
# 265              0             40            1
# 266              1              1         None
# 267              1              1         None
# 268              1              1         None
# 269              0            103            1
# 270              6              1         None
# 271              0              4         None
# 272              0              4         None
# 273              1              0         None
# 274              0            264         None
# 275              0              2         None
# 276              0             57         None
# 277              0            105         None
# 278              0              7         None
# 279              0              6         None
# 280              3              2         None
# 281              8              2         None
# 282              5              1         None
# 283              2              1         None
# 284              2              1         None
# 285              4              1            1
# 286              3              1         None
# 287              7              4         None
#
# [288 rows x 6 columns]
